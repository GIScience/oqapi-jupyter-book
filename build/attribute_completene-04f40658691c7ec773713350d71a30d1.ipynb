# %% [markdown]
# # Attributvollständigkeit

# %% [markdown]
# Der Attribute Completeness-Indikator leitet das Verhältnis von OSM-Features ab, die ein oder mehrere Attribute besitzen. Abhängig vom Feature kannst du aus einer unterschiedlichen Auswahl an Attributen wählen. Wenn du mehr als ein Attribut in einer query auswählst, werden die Ergebnisse kombiniert und die Ergebnisgrafik zeigt den Prozentsatz aller Features, die alle ausgewählten Attribute besitzen.
#
# <div>
# <img src="../abbildungen/attributvollständigkeit.png" width="300"/>
# </div>
#
#
# In diesem Drop-down-Menü kannst du ein oder mehrere Attribute auswählen.
#
# ## Methodik
# -> Intrinsischer Ansatz
#
# Berechnet den Prozentsatz der Features, die ein bestimmtes Attribut enthalten. Wenn das untersuchte Feature eine Liniengeometrie ist, wird die Quote basierend auf der Länge in km berechnet. Für Geometrien vom Typ node wird die Gesamtanzahl aller Features mit der Anzahl der Features verglichen, die die ausgewählten Attribute aufweisen.
#
# ## Result figure
# Die Ergebnisse der Abfrage findest du im Ergebnisprotokoll unten.
# Das grüne, gelbe oder rote Banner oben links zeigt den Completeness-Level an.
#
# Es gibt drei Qualitätskategorien:
# - niedrige Completeness < 25%
# - mittlere Completeness 25% - 75%
# - hohe Completeness > 75%
#
# Die Schwellenwerte für die Qualitätskategorien wurden durch die Betrachtung der Quotenverteilung vieler Gebiete und Attribute festgelegt und sollten nicht als objektive Metrik verstanden werden.
#
# ## Beispiel
#
# In folgendem Beispiel sehen wir wie wichtig es ist, das richtige Topic auszuwählen. Wir wollen die Attributvollständigkeit der Straßennamen für die frankfurter Innenstadt herausfinden.
#
# Auf dieser Abbildung sehen wir das Ergebnis für das Topic Straßen(all highways). Knapp 40% ist eine mittelmäßige Vollständigkeit und ein überraschendes Ergebnis für eine deutsche Großstadt. Spätestens jetzt muss uns auffallen, dass hier etwas eventuell nicht ganz stimmt. Das Topic Straßen(all highways) beinhaltet nicht nur von Autos befahrbare Straßen, sondern sämtliche Wege für motorisierten Verkehr, Rad- und Fußwege. Da viele Rad- und Fußwege keinen expliziten Namen haben, ist das Ergebnis der Abfrage nur knapp 40%.
#
# <div>
# <img src="../abbildungen/attributvollständigkeit_frankfurt.png" width="700"/>
# </div>
#
# Wenn wir uns nur für die Straßennamen der Straßen für motorisierten Verkehr interessieren, entscheiden wir uns für das Topic Straßen(Autos). In der nächsten Abbildung sehen wir, dass wir nun für dasselbe Untersuchungsgebiet eine hohe Vollständigkeit erhalten.
#
# <div>
# <img src="../abbildungen/attributvollständigkeit_frankfurt_autos.png" width="700"/>
# </div>
